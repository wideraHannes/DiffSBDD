# %%
from getpass import getpass

token = getpass("Token from Forge: ")

# %%
from esm.sdk import client

model = client(
    model="esmc-300m-2024-12", url="https://forge.evolutionaryscale.ai", token=token
)

# %%
from esm.sdk.api import (
    ESM3InferenceClient,
    ESMProtein,
    LogitsConfig,
    LogitsOutput,
)

EMBEDDING_CONFIG = LogitsConfig(
    sequence=True, return_embeddings=True, return_hidden_states=True
)


def embed_sequence(model: ESM3InferenceClient, path) -> LogitsOutput:
    protein = ESMProtein.from_pdb(path)
    protein_tensor = model.encode(protein)
    output = model.logits(protein_tensor, EMBEDDING_CONFIG)
    return output



embedding = embed_sequence(model, "../test_data/val/1amr-A-rec-1aia-pmp-lig-tt-docked-0-pocket10.pdb")


embedding
# Out:
# /Users/hanneswidera/Uni/Master/thesis/DiffSBDD/.venv/lib/python3.10/site-packages/esm/utils/misc.py:275: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x)
# LogitsOutput(logits=ForwardTrackData(sequence=tensor([[-38.0859, -38.0949, -38.1053,  ..., -38.1104, -38.1425, -38.1369],
#         [-37.3101, -37.3237, -37.3614,  ..., -37.3267, -37.3535, -37.3517],
#         [-32.1770, -32.1752, -32.2001,  ..., -32.2405, -32.2385, -32.2181],
#         ...,
#         [-33.5750, -33.5977, -33.6424,  ..., -33.6750, -33.6827, -33.6369],
#         [-31.1890, -31.2309, -31.2481,  ..., -31.2445, -31.2893, -31.2470],
#         [-30.9164, -30.9297, -30.9619,  ..., -30.9593, -30.9977, -30.9643]]), structure=None, secondary_structure=None, sasa=None, function=None), embeddings=tensor([[[ 6.0654e-04,  1.5335e-03,  5.7373e-03,  ...,  1.5137e-02,
#            2.1057e-03, -3.0975e-03],
#          [-3.0029e-02,  2.5482e-03,  6.1279e-02,  ...,  3.9795e-02,
#            2.1851e-02,  2.4658e-02],
#          [-2.6978e-02, -1.8921e-03,  1.4404e-02,  ...,  7.7515e-03,
#           -4.3030e-03,  2.4414e-03],
#          ...,
#          [-3.9795e-02, -4.8161e-05,  5.7983e-03,  ..., -1.7212e-02,
#           -5.7983e-03,  2.6398e-03],
#          [-1.9409e-02, -7.1106e-03,  2.9602e-03,  ...,  1.3580e-03,
#           -1.3123e-02, -1.2878e-02],
#          [-6.3477e-03,  1.9165e-02,  1.7944e-02,  ..., -3.7384e-04,
#            1.4572e-03, -7.5073e-03]]], dtype=torch.bfloat16), residue_annotation_logits=None, hidden_states=tensor([[[[-5.1953e-01,  2.8906e-01, -1.3184e-01,  ..., -3.3789e-01,
#            -1.6992e-01,  9.1406e-01],
#           [ 5.9766e-01, -8.4766e-01,  3.7109e-01,  ..., -1.5442e-02,
#             3.4180e-02, -8.7891e-01],
#           [ 5.9766e-01, -8.4766e-01,  3.7109e-01,  ..., -1.5442e-02,
#             3.4180e-02, -8.7891e-01],
#           ...,
#           [-7.3438e-01, -6.4453e-01, -2.3125e+00,  ..., -8.5938e-01,
#             9.5312e-01, -8.1641e-01],
#           [ 5.9766e-01, -8.4766e-01,  3.7109e-01,  ..., -1.5442e-02,
#             3.4180e-02, -8.7891e-01],
#           [ 2.2461e-01,  1.9629e-01,  1.6328e+00,  ...,  3.9062e-02,
#            -3.5742e-01, -2.5977e-01]]],
#
#
#         [[[-5.1172e-01,  1.8359e-01, -1.7090e-01,  ..., -2.9492e-01,
#             3.0078e-01,  5.5078e-01],
#           [ 2.4219e-01, -7.7734e-01, -4.8633e-01,  ...,  3.1836e-01,
#             2.3242e-01, -6.4844e-01],
#           [-3.7305e-01, -2.8516e-01, -4.8242e-01,  ...,  4.3164e-01,
#             4.0430e-01, -6.4844e-01],
#           ...,
#           [-5.6641e-02, -5.5078e-01, -2.0156e+00,  ..., -1.1250e+00,
#             9.3359e-01, -9.2188e-01],
#           [-5.0354e-03, -1.3047e+00, -5.0391e-01,  ...,  1.8359e-01,
#             1.1328e-01, -2.0312e+00],
#           [ 5.6885e-02, -4.6082e-03,  1.2578e+00,  ...,  1.9653e-02,
#             4.0039e-02, -5.1953e-01]]],
#
#
#         [[[-4.8438e-01,  2.7734e-01, -1.0010e-01,  ..., -3.0664e-01,
#             3.6719e-01,  6.7188e-01],
#           [ 8.3594e-01, -1.0986e-01, -6.0156e-01,  ...,  1.8457e-01,
#             8.5449e-02, -7.9688e-01],
#           [-2.3438e-01,  1.6504e-01, -1.9531e-01,  ...,  6.8750e-01,
#             7.0312e-01, -3.2812e-01],
#           ...,
#           [ 6.4453e-01, -3.4375e-01, -1.5547e+00,  ..., -7.6172e-01,
#             4.3359e-01, -8.8672e-01],
#           [-2.6953e-01, -1.2188e+00, -1.0742e-01,  ...,  4.0625e-01,
#             2.0215e-01, -2.9844e+00],
#           [-6.4850e-04,  6.0791e-02,  1.3828e+00,  ..., -8.4473e-02,
#             2.3926e-01, -4.9805e-01]]],
#
#
#         ...,
#
#
#         [[[-2.7250e+01,  1.4250e+01, -3.5000e+01,  ...,  7.6250e+00,
#             2.8125e+01, -5.0750e+01],
#           [-1.8250e+01,  1.3125e+01,  3.2750e+01,  ...,  9.6250e+00,
#             1.7625e+01, -3.4531e+00],
#           [-3.1125e+01,  8.3125e+00,  3.1750e+01,  ...,  1.4766e+00,
#            -4.5500e+01, -1.7000e+01],
#           ...,
#           [-2.8125e+01, -2.2375e+01,  1.6375e+01,  ..., -3.6500e+01,
#             7.2500e+01, -3.4000e+01],
#           [-1.8750e+01, -5.6000e+01,  2.8875e+01,  ...,  1.7250e+01,
#             1.0000e+01, -4.6250e+00],
#           [-1.7656e+00,  3.7750e+01,  1.2188e+01,  ..., -1.2562e+01,
#             3.2000e+01, -1.4000e+01]]],
#
#
#         [[[ 2.2125e+01,  4.0000e+00, -2.6875e+01,  ...,  2.3250e+01,
#             2.8000e+01, -4.0750e+01],
#           [-4.3000e+01, -9.5000e+00,  4.9750e+01,  ...,  4.6250e+01,
#            -5.3125e-01,  5.0500e+01],
#           [-6.3500e+01, -5.9062e+00,  2.8906e-01,  ..., -1.3562e+01,
#            -5.7750e+01, -1.6375e+01],
#           ...,
#           [-7.5500e+01, -2.7750e+01, -4.5000e+01,  ..., -8.4000e+01,
#             1.3125e+01,  1.3000e+01],
#           [-6.6500e+01, -4.2000e+01, -1.1000e+01,  ..., -6.2812e+00,
#             1.7375e+01, -2.1875e+01],
#           [ 2.9125e+01,  4.4250e+01, -1.5500e+01,  ..., -2.4500e+01,
#             3.5500e+01, -3.6562e+00]]],
#
#
#         [[[ 6.0654e-04,  1.5335e-03,  5.7373e-03,  ...,  1.5137e-02,
#             2.1057e-03, -3.0975e-03],
#           [-3.0029e-02,  2.5482e-03,  6.1279e-02,  ...,  3.9795e-02,
#             2.1851e-02,  2.4658e-02],
#           [-2.6978e-02, -1.8921e-03,  1.4404e-02,  ...,  7.7515e-03,
#            -4.3030e-03,  2.4414e-03],
#           ...,
#           [-3.9795e-02, -4.8161e-05,  5.7983e-03,  ..., -1.7212e-02,
#            -5.7983e-03,  2.6398e-03],
#           [-1.9409e-02, -7.1106e-03,  2.9602e-03,  ...,  1.3580e-03,
#            -1.3123e-02, -1.2878e-02],
#           [-6.3477e-03,  1.9165e-02,  1.7944e-02,  ..., -3.7384e-04,
#             1.4572e-03, -7.5073e-03]]]], dtype=torch.bfloat16))

# %%
import torch

# we'll summarize the embeddings using their mean across the sequence dimension
# which allows us to compare embeddings for sequences of different lengths

mean_embedding =  torch.mean(embedding.hidden_states, dim=-2).squeeze()


# now we have a list of tensors of [num_layers, hidden_size]
print("embedding shape [num_layers, hidden_size]:", mean_embedding.shape)
# Out:
# embedding shape [num_layers, hidden_size]: torch.Size([31, 960])

# %%
last_layer_embedding = mean_embedding[30, :]
last_layer_embedding.shape
# Out:
# torch.Size([960])

# %%
# write a function that extracts from val all pdb file paths as strings and returns them as a list
"../test_data/val/1amr-A-rec-1aia-pmp-lig-tt-docked-0-pocket10.pdb"

def get_pdb_file_paths(val_dir: str) -> list[str]:
    import os

    pdb_file_paths = []
    for root, dirs, files in os.walk(val_dir):
        for file in files:
            if file.endswith(".pdb"):
                pdb_file_paths.append(os.path.join(root, file))
    return pdb_file_paths


pdb_file_paths = get_pdb_file_paths("../test_data/val")
pdb_file_paths[:5]
# Out:
# ['../test_data/val/3fr5-A-rec-3p6f-fbz-lig-tt-min-0-pocket10.pdb',
#  '../test_data/val/3hwf-A-rec-1x71-db1-lig-tt-min-0-pocket10.pdb',
#  '../test_data/val/2wzh-A-rec-5fl0-71i-lig-it1-it2-tt-docked-3-pocket10.pdb',
#  '../test_data/val/2zjw-A-rec-3mb6-01i-lig-tt-min-0-pocket10.pdb',
#  '../test_data/val/4l7d-A-rec-5fzn-fb2-lig-tt-min-0-pocket10.pdb']

# %% [markdown]
# ## Put it all together
#
# Now that we have all puzzle pieces together create a graph visualizing all embeddings

# %%
EMBEDDING_CONFIG = LogitsConfig(
    sequence=True, return_embeddings=True, return_hidden_states=True
)

def embed_sequence(model: ESM3InferenceClient, path, layer:int=30) -> LogitsOutput:
    protein = ESMProtein.from_pdb(path)
    protein_tensor = model.encode(protein)
    output = model.logits(protein_tensor, EMBEDDING_CONFIG)
    # we'll summarize the embeddings using their mean across the sequence dimension
    # which allows us to compare embeddings for sequences of different lengths
    mean_embedding =  torch.mean(output.hidden_states, dim=-2).squeeze()
    layer_embedding = mean_embedding[layer, :]
    return layer_embedding

embedding = embed_sequence(model, "../test_data/val/1amr-A-rec-1aia-pmp-lig-tt-docked-0-pocket10.pdb")
# Out:
# tensor([-1.7334e-02,  1.1673e-03,  1.7334e-02,  9.9487e-03,  6.4697e-03,
#          5.7861e-02,  1.6235e-02, -2.1515e-03, -9.2163e-03, -6.9580e-03,
#          5.3406e-03,  4.4861e-03,  1.1169e-02, -2.9144e-03, -2.0874e-02,
#         -1.3916e-02,  5.3101e-03, -9.5825e-03, -7.5378e-03, -5.5847e-03,
#          7.2754e-02,  1.1353e-02,  2.5024e-02,  3.2617e-01, -8.2397e-03,
#         -5.3101e-03, -1.8921e-02,  1.1475e-02,  1.0010e-02, -5.5542e-03,
#         -5.7068e-03,  2.4902e-02, -2.8198e-02,  1.4893e-02,  1.4648e-02,
#          9.7046e-03,  7.7248e-05,  1.0132e-02, -3.0640e-02, -1.2085e-02,
#         -1.8921e-03, -2.7588e-02, -1.9897e-02,  1.3428e-02,  1.5747e-02,
#         -1.2268e-02, -3.1006e-02, -1.2634e-02,  4.7607e-03, -1.2634e-02,
#         -1.4893e-02, -3.5889e-02, -1.4282e-02,  5.8899e-03, -8.6670e-03,
#          1.0071e-02, -4.1199e-03, -1.6357e-02,  6.7749e-03,  3.3936e-02,
#         -2.9663e-02,  4.3030e-03, -1.8677e-02, -2.1606e-02, -2.0508e-02,
#         -8.3618e-03, -6.5308e-03,  2.2583e-02, -1.4893e-02,  1.0559e-02,
#          2.5513e-02,  1.2024e-02, -6.0120e-03, -1.5503e-02, -2.3438e-02,
#         -6.9427e-04,  2.8076e-02, -1.2451e-02, -7.6599e-03,  1.4343e-02,
#         -6.3171e-03, -2.7771e-03, -5.5908e-02,  1.5991e-02,  9.5825e-03,
#          5.9204e-03, -5.5908e-02, -6.9275e-03, -1.8799e-02,  6.6528e-03,
#          1.1841e-02,  1.9897e-02,  3.5400e-02, -1.5381e-02,  8.2397e-03,
#         -6.1951e-03,  2.0409e-04,  1.4191e-03, -2.5879e-02,  1.1169e-02,
#         -3.7109e-02, -1.2085e-02, -4.6349e-04, -5.0659e-03, -4.8523e-03,
#          2.1973e-03, -1.1108e-02, -2.6611e-02,  2.6123e-02,  8.4839e-03,
#         -1.0803e-02,  2.1851e-02, -1.2390e-02, -7.3547e-03, -1.7700e-02,
#          7.7820e-03, -2.2461e-02, -4.8523e-03, -2.0264e-02,  5.4932e-03,
#          1.8555e-02, -1.9989e-03, -1.9073e-03, -3.9551e-02,  4.0283e-03,
#          8.2016e-04,  2.4170e-02, -1.7090e-02, -2.5146e-02,  9.0408e-04,
#          2.0386e-02, -5.7068e-03,  1.8066e-02,  1.3123e-02,  8.7891e-03,
#         -6.9580e-03, -3.1738e-02, -4.3457e-02, -2.0386e-02, -3.1128e-02,
#         -1.8005e-03, -1.0681e-02,  1.4771e-02, -1.3184e-02, -1.6479e-03,
#          2.6978e-02,  7.3853e-03,  4.5166e-03,  7.2021e-03, -7.4463e-03,
#          1.0132e-02,  1.3489e-02,  1.9653e-02, -4.3030e-03,  4.0527e-02,
#          1.9043e-02, -1.9531e-02,  2.1484e-02,  3.3936e-02,  1.9409e-02,
#         -8.7891e-03, -2.7161e-03,  1.7090e-03, -1.9302e-03, -2.9175e-02,
#         -1.1475e-02, -2.2095e-02,  1.2878e-02,  1.0010e-02,  8.2397e-04,
#         -7.1411e-03, -8.7891e-03, -9.7046e-03, -4.5410e-02, -9.7656e-03,
#          1.7944e-02, -2.0752e-02,  7.6904e-03, -3.0884e-02,  1.0452e-03,
#          3.1494e-02, -2.5879e-02,  9.6436e-03, -9.6436e-03, -7.8583e-04,
#         -1.0742e-02, -4.5654e-02, -8.7280e-03, -2.4780e-02, -3.0365e-03,
#         -1.3306e-02,  7.3242e-03,  2.6367e-02,  7.0496e-03,  9.6436e-03,
#          4.9744e-03,  9.0790e-04,  1.1475e-02, -2.2583e-03,  3.1891e-03,
#         -1.3489e-02,  5.9204e-03,  3.3264e-03,  3.4668e-02, -3.8086e-02,
#         -5.2490e-03, -3.0823e-03,  1.3733e-02,  1.2390e-02,  6.8750e-01,
#         -2.5391e-02,  1.2695e-02,  4.2578e-01, -7.5378e-03,  8.1177e-03,
#         -3.5645e-02, -3.5553e-03, -3.3936e-02, -2.0996e-02,  5.6458e-03,
#          1.5717e-03, -2.1240e-02,  6.7749e-03,  1.5015e-02, -2.1118e-02,
#          3.0273e-02, -2.1057e-03,  9.8877e-03, -4.9133e-03,  1.5747e-02,
#         -6.2561e-03, -1.6724e-02, -1.3199e-03, -2.0264e-02, -4.1016e-02,
#         -2.4292e-02, -9.0332e-03,  2.8809e-02, -1.1841e-02, -1.8555e-02,
#         -2.5146e-02,  9.8419e-04, -7.1411e-03, -6.9580e-03,  2.8809e-02,
#         -1.3916e-02,  1.7014e-03, -1.4465e-02, -4.0771e-02, -4.6997e-03,
#         -2.5513e-02,  6.5994e-04, -9.8267e-03,  2.0264e-02, -9.5825e-03,
#         -1.5335e-03,  2.4414e-02,  1.7480e-01, -2.0874e-02,  5.8594e-03,
#         -1.2695e-02,  9.3384e-03,  5.8289e-03, -7.3624e-04, -4.3945e-02,
#          4.5586e-04,  4.0283e-03, -8.5449e-03,  9.5215e-03,  2.7924e-03,
#          3.8452e-03,  1.3672e-02,  1.0910e-03, -5.8289e-03,  1.1841e-02,
#          3.1586e-03,  2.6855e-02, -3.4912e-02,  1.2878e-02, -1.2024e-02,
#          1.0193e-02,  7.0801e-03,  3.9551e-02, -3.1662e-04,  2.6855e-03,
#          2.0996e-02, -1.0010e-02, -2.3926e-02,  6.9275e-03,  2.0386e-02,
#          1.6846e-02, -1.9531e-02, -2.7275e-04, -5.1880e-03, -3.0060e-03,
#          7.7820e-03, -1.5503e-02,  1.3428e-02,  1.8433e-02, -1.0864e-02,
#          1.7822e-02, -1.5747e-02, -5.2795e-03, -6.2866e-03,  2.4048e-02,
#          1.0452e-03, -7.2632e-03,  2.4048e-02,  2.3315e-02,  6.8359e-03,
#         -1.3184e-02,  4.2480e-02,  4.4632e-04, -1.3428e-02, -4.4922e-02,
#         -1.4160e-02,  2.3193e-03, -1.5076e-02, -1.0254e-02,  5.9814e-03,
#         -7.9346e-04,  1.6113e-02, -2.1362e-03,  3.4180e-03, -8.6060e-03,
#         -6.9580e-03,  7.8125e-03, -1.3855e-02, -3.2959e-02,  1.1719e-02,
#          4.7913e-03, -8.1787e-03, -5.4169e-04,  2.0264e-02,  4.3640e-03,
#         -9.8267e-03, -2.5146e-02, -9.7046e-03,  1.8311e-02,  8.6670e-03,
#         -1.7090e-02,  4.7302e-03,  1.1536e-02, -4.9744e-03,  1.0498e-02,
#          2.7618e-03, -1.1414e-02, -5.3711e-03, -1.4587e-02, -4.8218e-03,
#          2.3499e-03, -1.2817e-02,  2.2217e-02,  2.8687e-03,  4.6082e-03,
#          1.6602e-02, -3.2471e-02, -1.8692e-04,  8.3008e-03,  4.6387e-03,
#         -2.9907e-02, -3.7842e-02,  3.2959e-02, -1.7944e-02,  1.6724e-02,
#         -9.0408e-04, -7.4768e-03, -4.0771e-02,  2.2583e-03, -4.7607e-03,
#          8.9722e-03, -6.7444e-03, -2.2221e-04, -1.6968e-02, -1.7700e-02,
#          6.0120e-03,  1.9897e-02, -9.6436e-03,  1.4400e-04, -7.7515e-03,
#          1.2741e-03,  1.0376e-02,  1.6846e-02,  2.5177e-03,  2.1973e-02,
#          1.0437e-02, -8.9111e-03, -1.0193e-02,  8.5449e-03, -8.1787e-03,
#         -9.8267e-03,  9.3994e-03, -2.8992e-03, -3.0365e-03, -7.7820e-04,
#          7.5989e-03,  3.6716e-05, -3.1128e-03,  1.2451e-02, -2.6855e-02,
#          2.0142e-02, -1.7822e-02,  3.2227e-02,  3.5095e-03, -6.6528e-03,
#         -1.1047e-02,  2.2949e-02, -2.1484e-02,  8.4839e-03,  8.7891e-03,
#         -3.1128e-03,  1.0437e-02,  2.1484e-02, -7.9346e-03, -6.8054e-03,
#          1.8799e-02,  8.1177e-03,  1.5564e-02,  1.4954e-03, -1.4771e-02,
#         -1.3062e-02,  3.1738e-02, -1.0986e-02, -1.1963e-02,  9.7656e-03,
#         -9.0408e-04, -2.4292e-02, -2.2461e-02,  3.7354e-02, -4.4556e-03,
#         -8.2397e-03, -7.3730e-02, -3.4180e-03, -1.8188e-02, -1.6846e-02,
#         -5.3711e-02,  2.8992e-03, -2.1606e-02,  5.9204e-03,  2.4780e-02,
#          6.8665e-03, -1.5640e-04, -2.0508e-02, -1.6357e-02,  4.2236e-02,
#          3.0518e-03,  1.5625e-02, -2.8839e-03,  6.0120e-03, -7.5684e-03,
#          1.2085e-02,  3.2959e-02, -5.0354e-03, -2.3315e-02, -2.0752e-02,
#          2.8198e-02,  1.8311e-02, -2.5757e-02,  1.2390e-02, -1.2779e-04,
#         -5.2795e-03,  9.3994e-03,  3.2227e-02,  8.9722e-03,  2.1973e-02,
#         -1.7578e-02, -4.4189e-02, -3.0396e-02, -1.3611e-02,  3.8300e-03,
#         -1.1292e-02, -2.5879e-02,  1.8799e-02, -1.5442e-02, -1.7334e-02,
#         -1.0193e-02,  1.3367e-02,  2.0264e-02, -1.0193e-02,  2.7771e-03,
#         -4.6387e-03,  9.5825e-03, -2.2339e-02, -2.5146e-02, -1.6113e-02,
#         -1.1520e-03,  2.0752e-02,  2.3193e-02,  1.7456e-02,  7.4768e-03,
#         -1.1169e-02, -2.1362e-02,  2.5269e-02, -1.8539e-03,  4.3457e-02,
#          5.5542e-03,  1.3184e-02, -1.6327e-03, -1.9165e-02, -4.5471e-03,
#         -2.5635e-03,  1.7700e-02,  1.3000e-02,  2.9541e-02, -2.7161e-03,
#         -2.5146e-02, -2.2705e-02,  3.9062e-03,  1.8311e-02, -2.4567e-03,
#          5.0049e-03, -3.2715e-02,  8.2397e-03,  3.4332e-04,  1.2512e-02,
#         -1.5320e-02,  1.7944e-02, -2.7100e-02,  1.1414e-02, -6.3171e-03,
#         -3.2806e-03, -1.4465e-02,  4.3030e-03, -2.7466e-04, -2.5757e-02,
#         -2.3315e-02,  1.0925e-02,  4.6539e-04,  1.4404e-02, -1.5381e-02,
#          4.1504e-03, -2.6611e-02, -6.1646e-03, -9.6436e-03, -5.4321e-03,
#         -4.3335e-03, -1.7212e-02,  1.1841e-02,  1.0437e-02,  2.3193e-03,
#         -5.9204e-03, -2.9297e-02,  3.0884e-02,  1.8692e-03, -4.5166e-03,
#         -7.0801e-02, -1.3489e-02,  1.7212e-02,  8.7280e-03,  1.1658e-02,
#         -9.0332e-03,  1.7285e-05,  3.2471e-02, -1.0681e-02, -1.2878e-02,
#         -1.4648e-02,  2.3315e-02, -2.2339e-02,  1.9043e-02, -2.1362e-02,
#         -7.9346e-03, -2.5146e-02, -1.8066e-02, -1.3550e-02, -5.5847e-03,
#          1.0620e-02, -7.9956e-03,  1.9409e-02, -1.7853e-03, -1.9409e-02,
#         -1.5640e-03, -2.5024e-02,  5.6152e-03, -5.6458e-03, -3.6316e-03,
#         -5.7129e-02, -5.1025e-02,  2.5757e-02, -4.7302e-03, -2.6367e-02,
#          8.7280e-03,  3.2227e-02, -3.0029e-02, -3.8330e-02,  2.9564e-04,
#         -1.9165e-02, -3.4485e-03, -1.6602e-02,  3.0060e-03, -6.9885e-03,
#         -3.5889e-02,  2.8687e-02,  9.3359e-01,  2.2705e-02, -1.4038e-02,
#         -1.3916e-02, -1.8311e-02, -8.1177e-03,  1.3489e-02, -2.6398e-03,
#         -1.0498e-02,  9.0942e-03,  3.3691e-02,  3.1494e-02, -3.1006e-02,
#         -1.4038e-02,  1.3428e-03,  2.1118e-02, -2.9053e-02,  4.7913e-03,
#         -2.5391e-02,  1.1902e-02,  1.3184e-02, -1.4648e-02,  2.6367e-02,
#          8.9111e-03,  1.9455e-03,  7.1716e-03,  3.9368e-03,  3.0823e-03,
#          2.1667e-03, -1.8433e-02,  1.5411e-03, -5.0354e-03,  1.3794e-02,
#         -1.2024e-02, -1.3855e-02,  1.8066e-02, -2.7954e-02, -3.3569e-03,
#          2.6978e-02, -1.7822e-02, -4.1809e-03, -1.5991e-02, -2.5269e-02,
#          1.8311e-03, -2.4109e-03, -3.1738e-03,  1.8433e-02, -2.3071e-02,
#          1.6357e-02,  7.7057e-04, -7.4463e-03, -1.0559e-02, -2.5513e-02,
#          9.3994e-03,  1.0071e-02, -1.0193e-02,  5.6763e-03,  1.8555e-02,
#          1.3672e-02,  3.5645e-02, -2.3682e-02, -2.1973e-02, -4.7913e-03,
#         -1.6357e-02,  3.1738e-02, -2.5024e-02,  2.5513e-02, -1.9836e-03,
#         -1.6479e-02,  2.8442e-02,  8.5449e-04, -5.0049e-03,  7.7515e-03,
#         -5.7983e-03, -6.7749e-03, -2.1729e-02,  1.2146e-02, -5.2795e-03,
#          1.1536e-02,  3.5156e-02, -4.3335e-03, -3.5286e-04,  4.2725e-03,
#         -6.2561e-03,  2.8198e-02, -1.5831e-04,  5.1270e-03, -2.3926e-02,
#          3.9673e-03,  2.0874e-02, -4.6143e-02,  1.5564e-02, -1.5991e-02,
#          1.9043e-02, -1.3306e-02,  2.4292e-02,  1.6113e-02,  2.3560e-02,
#         -1.5747e-02,  8.1787e-03,  1.1169e-02, -2.1729e-02,  8.7891e-03,
#         -2.1240e-02, -6.8359e-03, -6.6223e-03,  1.6602e-02, -2.2461e-02,
#         -2.0020e-02,  1.5259e-02,  1.6968e-02,  1.4954e-02, -1.0803e-02,
#         -2.8198e-02, -5.1575e-03,  1.1169e-02,  5.5237e-03,  5.8413e-05,
#          1.0254e-02, -2.9175e-02, -3.8818e-02,  7.1106e-03,  1.9775e-02,
#          1.4099e-02, -1.6479e-02,  1.8921e-02, -7.7820e-03,  2.0996e-02,
#         -7.3853e-03, -1.1230e-02, -3.4424e-02,  1.6724e-02,  2.5977e-01,
#          6.1646e-03, -2.6611e-02, -7.5989e-03,  1.4282e-02,  6.3477e-03,
#         -2.4536e-02,  3.8086e-02, -1.0864e-02,  1.4465e-02, -2.3315e-02,
#          2.6093e-03,  3.0365e-03, -1.3977e-02, -7.8735e-03, -8.7891e-03,
#         -1.1841e-02,  3.1982e-02,  5.0659e-03,  1.7456e-02, -3.1006e-02,
#         -1.0071e-02, -1.5869e-02, -1.2085e-02, -1.7456e-02, -7.8735e-03,
#         -1.8921e-02,  1.9165e-02, -1.0925e-02,  3.4027e-03, -3.5095e-03,
#          2.6245e-03,  5.5542e-03,  3.1128e-03, -2.3071e-02, -2.8809e-02,
#          1.0498e-02,  2.1362e-03,  8.5449e-03,  9.7656e-03, -8.9111e-03,
#          6.0654e-04,  1.0559e-02,  1.0071e-02, -2.4048e-02,  9.3994e-03,
#          3.6133e-02, -4.6082e-03, -5.3406e-03,  9.8267e-03, -5.9814e-03,
#         -3.3447e-02,  1.4587e-02, -3.2471e-02,  1.0681e-02,  3.2471e-02,
#          1.2634e-02,  4.1199e-03,  1.0376e-02, -2.7924e-03,  9.2163e-03,
#          1.2024e-02, -2.9907e-03, -3.6377e-02, -5.0964e-03, -1.8799e-02,
#         -1.3916e-02, -2.3071e-02, -1.2970e-04,  1.3733e-02,  3.8330e-02,
#          3.9062e-03,  1.3123e-02, -1.8082e-03, -9.1553e-03,  3.2501e-03,
#         -1.0681e-02, -7.7209e-03,  2.9175e-02, -6.6223e-03, -1.0376e-02,
#         -1.6846e-02, -2.7222e-02,  7.3853e-03, -7.9102e-02, -4.8828e-04,
#          2.4048e-02,  1.8555e-02,  3.0518e-02,  4.9744e-03, -1.2390e-02,
#         -2.5940e-03, -1.3000e-02, -5.5847e-03, -2.2095e-02, -1.8311e-02,
#         -3.0670e-03,  1.9165e-02, -2.3071e-02,  1.7090e-02,  4.3945e-03,
#          3.0884e-02, -3.9307e-02, -1.7090e-02,  2.6733e-02,  1.0010e-02,
#          1.0193e-02,  2.8534e-03,  2.3560e-02,  1.3504e-03,  8.7891e-03,
#         -4.7607e-02, -2.0905e-03,  6.5918e-03,  1.4282e-02, -2.1362e-02,
#         -1.2512e-02, -1.2939e-02, -1.0376e-02, -1.3672e-02,  1.7090e-02,
#          3.0327e-04,  1.2207e-02,  3.0396e-02,  2.5940e-03, -1.5442e-02,
#         -2.0630e-02,  8.1787e-03, -2.0264e-02, -1.0071e-02,  6.3782e-03,
#         -2.7466e-02, -2.6398e-03,  2.1820e-03, -2.4048e-02,  3.5858e-03,
#         -1.0986e-02, -1.3733e-02,  1.2360e-03, -9.2773e-03,  1.4954e-02,
#          2.3438e-02,  2.5879e-02, -2.7344e-02,  8.5449e-03, -2.0142e-02,
#          3.1128e-03,  2.0508e-02, -1.1963e-02,  1.1047e-02,  3.7689e-03,
#         -2.1118e-02, -1.8433e-02, -1.5488e-03, -9.7046e-03,  7.6904e-03,
#          1.9531e-02, -1.6235e-02,  1.2573e-02, -9.5215e-03,  1.5259e-02,
#          1.8234e-03,  8.9722e-03,  1.6113e-02, -5.8289e-03,  3.8605e-03,
#         -1.8799e-02, -2.0386e-02, -2.6367e-02, -2.1973e-02, -8.7280e-03,
#          4.5166e-03, -1.5564e-02, -2.8442e-02,  1.3428e-02,  4.1809e-03,
#          1.7822e-02, -5.8289e-03, -1.8188e-02,  1.0132e-02, -1.7456e-02,
#         -1.0803e-02,  5.4321e-03, -4.8523e-03, -2.0142e-03,  6.6376e-04,
#         -1.0864e-02,  1.6022e-03, -1.6861e-03, -8.0566e-03,  2.5024e-03,
#         -1.5503e-02,  1.4832e-02, -6.7139e-03, -3.9978e-03,  6.0425e-03,
#          8.3008e-03, -6.5002e-03,  2.0264e-02, -2.1362e-02, -5.5847e-03,
#         -1.3855e-02,  1.2146e-02,  2.1362e-03, -4.1809e-03,  7.0190e-03,
#         -2.6978e-02,  4.7607e-03, -4.6680e-01, -4.0588e-03, -1.0071e-03,
#          3.5400e-02, -2.7832e-02, -1.0437e-02,  3.1494e-02, -2.6611e-02,
#         -4.2419e-03, -2.8801e-04,  2.1118e-02,  1.2512e-02,  9.0332e-03,
#          3.5706e-03,  3.5645e-02, -1.9043e-02, -3.8818e-02,  2.0874e-02,
#          6.1646e-03,  4.8218e-03,  5.0049e-03,  1.3199e-03, -1.6251e-03,
#         -7.0801e-03,  7.9956e-03,  7.7209e-03,  6.1646e-03, -3.0060e-03],
#        dtype=torch.bfloat16)

# %%
embeddings = [embed_sequence(model, path) for path in pdb_file_paths]
# Out:
# /Users/hanneswidera/Uni/Master/thesis/DiffSBDD/.venv/lib/python3.10/site-packages/esm/utils/misc.py:275: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   return torch.tensor(x)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 embeddings = [embed_sequence(model, path) for path in pdb_file_paths]
# ----> 2 embeddings.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
len(embeddings)
# Out:
# 50
